# %% [markdown]
# # Using SDSS-V Targeting Flags with `semaphore`
#
# ## Learning Goals
# By the end of this tutorial, you will:
# - How to select spectra by their targeting information
# - How to get the targeting information of a specific target
#
# ## Introduction
# The SDSS-V Survey uses a complex targeting schema, where targets are selected through many cartons associated with the different SDSS-V mappers and programs.
#
# In this short tutorial, we will briefly cover determining which targets in a summary file are associated with a particular carton, program, or master. It also describes how to determine the targeting information for a single source.
#
# ## Imports
#
# This tutorial requires two commonly used python packages and two SDSS specific packages
# - numpy for filtering of arrays
# - astropy for reading fits tables
# - sdss-access for accessing data on the SAS
# - semaphore for exploring the flags
#
# Missing packages can be installed via `pip install numpy astropy sdss-access sdss-tree sdss-semaphore>=0.2.8`
#
#
# NOTE: You may want to set the `$SAS_BASE_DIR` environment variable before starting this notebook, other wise `$HOME/sas` will be created and used

# %%
import os
os.environ['SDSSC2BV'] ='2' # to set the DR19 Carton to Bit Mapping Version

import numpy as np
from astropy.io import fits
from sdss_access import Access
from sdss_semaphore.targeting import TargetingFlags

# setup sdss_access for DR20
access = Access(release='dr20')

# %% [markdown]
# ## Load the Data
# We will use `sdss-access` to find/download the file. `sdss-access` has extensive [documentation](https://sdss-access.readthedocs.io/en/latest/), but we should mention a few things. First if you are a member of the collaboration accessing proprietary data, you need to set up a a [.netrc file](https://sdss-access.readthedocs.io/en/latest/auth.html). After that usage is the same for everyone.
#
# You need specify the file species you need, in this case 'mwmStar', then a series of key word arguments that vary depending on the file species. A list of file species and their keyword arugments is [available](https://sdss-access.readthedocs.io/en/latest/paths.html).
#
# The code below show an example of retreiving a summary file. access.full() builds the file path, access.exists() checks if the file exists, and access.commit() will retrieve the file and save it to your local SAS (`$SAS_BASE_DIR`) with the same structure as the SAS (so it will be many files deep).

# %%
filename = access.full('mwmAllVisit',v_astra = '0.6.0')
if not access.exists('',full=filename):
    # if the file does not exist locally, this code will download the data.
    access.remote()
    access.add('mwmAllVisit',v_astra = '0.6.0')
    access.set_stream()
    access.commit()
    filename = access.full('mwmAllVisit',v_astra = '0.6.0')

# %% [markdown]
# ### Open the file
# Now use `astropy.fitsio` to load the data
# - HDU 1 contains the BOSS Spectra
# - HDU 2 contains the APOGEE Spectra

# %%
hdul = fits.open(filename)
hdul[0].header
boss_data = hdul[1].data

# %% [markdown]
# ### Converting the stored column to a set of Targeting Flags
# Now use the semaphore package to convert the fits column to Targeting Flags

# %%
flags = TargetingFlags(boss_data["SDSS5_TARGET_FLAGS"])

# %%
# Let's count the number of targets assigned to each carton (and skip empty cartons)
for label, count in flags.count(skip_empty=True).items():
    print(f"{label}: {count}")
# Out:
# mwm_snc_100pc_0.1.0: 33542
# mwm_snc_250pc_0.1.0: 2019
# mwm_cb_300pc_0.1.0: 123
# mwm_cb_cvcandidates_0.1.0: 834
# mwm_halo_sm_0.1.0: 1642
# mwm_halo_bb_0.1.0: 31926
# mwm_yso_s1_0.1.0: 9514
# mwm_yso_s2_0.1.0: 44
# mwm_yso_s2-5_0.1.0: 3
# mwm_yso_s3_0.1.0: 15969
# mwm_yso_ob_0.1.0: 16
# mwm_yso_cluster_0.1.0: 16760
# mwm_rv_long-fps_0.1.0: 2507
# mwm_rv_long-bplates_0.1.0: 586
# mwm_ob_cepheids_0.1.0: 128
# mwm_rv_short-fps_0.1.0: 7162
# mwm_rv_short-bplates_0.1.0: 847
# mwm_ob_core_0.1.0: 101779
# mwm_rv_short-rm_0.1.0: 153
# mwm_rv_long-rm_0.1.0: 53
# ops_std_boss_0.1.0: 132780
# mwm_wd_core_0.1.0: 36240
# mwm_gg_core_0.1.0: 5264
# mwm_planet_tess_0.1.0: 4783
# bhm_aqmes_med_0.1.0: 1691
# mwm_cb_gaiagalex_0.1.0: 42430
# bhm_aqmes_med-faint_0.1.0: 3354
# mwm_tessrgb_core_0.1.0: 4707
# bhm_aqmes_wide3_0.1.0: 1718
# bhm_aqmes_wide3-faint_0.1.0: 2550
# bhm_aqmes_wide2_0.1.0: 1109
# bhm_aqmes_wide2-faint_0.1.0: 736
# bhm_aqmes_bonus-dark_0.1.0: 16725
# bhm_aqmes_bonus-bright_0.1.0: 1703
# bhm_csc_boss-dark_0.1.0: 38684
# bhm_csc_boss-bright_0.1.0: 3355
# bhm_csc_apogee_0.1.0: 247
# bhm_gua_dark_0.1.0: 9214
# bhm_gua_bright_0.1.0: 2404
# ops_std_eboss_0.1.0: 72758
# bhm_rm_core_0.1.0: 14296
# bhm_rm_known-spec_0.1.0: 27447
# bhm_rm_var_0.1.0: 5352
# bhm_rm_ancillary_0.1.0: 6669
# ops_std_boss-red_0.1.0: 12666
# bhm_spiders_agn-efeds_0.1.0: 786
# mwm_cb_uvex1_0.1.0: 20115
# mwm_cb_uvex2_0.1.0: 43381
# mwm_dust_core_0.1.0: 39
# mwm_cb_uvex3_0.1.0: 130
# mwm_cb_uvex4_0.1.0: 774
# mwm_cb_uvex5_0.1.0: 1133
# mwm_legacy_ir2opt_0.1.1: 21330
# ops_apogee_stds_0.1.2: 5070
# ops_std_boss_tic_0.1.3: 92123
# mwm_rv_long_bplates_0.1.4: 774
# ops_std_eboss_0.5.0: 72720
# ops_std_boss_0.5.0: 125936
# ops_std_boss_red_0.5.0: 12666
# ops_std_apogee_0.5.0: 5071
# mwm_cb_gaiagalex_apogee_0.5.0: 126
# mwm_cb_gaiagalex_boss_0.5.0: 42438
# mwm_cb_cvcandidates_boss_0.5.0: 834
# mwm_galactic_core_0.5.0: 5270
# mwm_cb_uvex3_0.5.0: 788
# mwm_cb_uvex4_0.5.0: 1189
# mwm_snc_100pc_boss_0.5.0: 33562
# mwm_snc_250pc_apogee_0.5.0: 1988
# mwm_snc_250pc_boss_0.5.0: 2019
# mwm_halo_sm_boss_0.5.0: 1640
# mwm_yso_disk_apogee_0.5.0: 9514
# mwm_yso_disk_boss_0.5.0: 12320
# mwm_yso_embedded_apogee_0.5.0: 45
# mwm_yso_nebula_apogee_0.5.0: 3
# mwm_yso_variable_apogee_0.5.0: 15975
# mwm_yso_variable_boss_0.5.0: 15599
# mwm_yso_ob_apogee_0.5.0: 16
# mwm_yso_ob_boss_0.5.0: 16
# mwm_yso_cmz_apogee_0.5.0: 244
# mwm_yso_cluster_apogee_0.5.0: 16763
# mwm_yso_cluster_boss_0.5.0: 22482
# mwm_rv_short_fps_0.5.0: 7163
# mwm_legacy_ir2opt_0.5.0: 21340
# mwm_dust_core_0.5.0: 36
# mwm_wd_core_0.5.0: 36240
# mwm_tess_planet_0.5.0: 5239
# mwm_snc_100pc_apogee_0.5.0: 1821
# mwm_cb_uvex1_0.5.0: 19771
# mwm_cb_uvex2_0.5.0: 43297
# mwm_tessrgb_core_0.5.0: 4707
# ops_std_boss_tic_0.5.0: 92133
# mwm_rv_long_fps_0.5.0: 2507
# mwm_halo_bb_boss_0.5.0: 31503
# mwm_cb_300pc_apogee_0.5.0: 96
# mwm_cb_300pc_boss_0.5.0: 123
# bhm_spiders_agn_gaiadr2_0.5.0: 5669
# bhm_spiders_agn_lsdr8_0.5.0: 3349
# bhm_spiders_agn_efeds_stragglers_0.5.0: 703
# bhm_spiders_agn_ps1dr2_0.5.0: 5845
# bhm_spiders_agn_skymapperdr2_0.5.0: 1588
# bhm_spiders_agn_supercosmos_0.5.0: 1879
# bhm_spiders_clusters_ps1dr2_0.5.0: 3
# bhm_gua_bright_0.5.0: 5055
# bhm_gua_dark_0.5.0: 19733
# mwm_cb_uvex5_0.5.0: 1133
# bhm_rm_known_spec_0.5.0: 27917
# bhm_rm_core_0.5.0: 14487
# bhm_rm_var_0.5.0: 5240
# bhm_rm_ancillary_0.5.0: 6667
# ops_std_boss_lsdr8_0.5.0: 50495
# ops_std_boss_ps1dr2_0.5.0: 124139
# ops_std_boss_gdr2_0.5.0: 122551
# bhm_aqmes_med_0.5.0: 1793
# bhm_aqmes_med_faint_0.5.0: 3826
# bhm_csc_boss_dark_0.5.0: 40560
# bhm_csc_boss_bright_0.5.0: 3546
# bhm_csc_apogee_0.5.0: 364
# mwm_yso_pms_apogee_0.5.1: 17838
# mwm_yso_pms_boss_0.5.1: 18395
# mwm_ob_core_0.5.1: 102006
# mwm_ob_cepheids_0.5.1: 129
# mwm_halo_bb_boss_0.5.1: 31576
# mwm_halo_sm_boss_0.5.1: 1642
# mwm_erosita_stars_0.5.2: 3015
# mwm_erosita_compact_gen_0.5.2: 955
# mwm_erosita_compact_var_0.5.2: 444
# openfibertargets_nov2020_25_0.5.2-test: 23078
# openfibertargets_nov2020_28a_0.5.2-test: 2027
# openfibertargets_nov2020_28b_0.5.2-test: 3129
# openfibertargets_nov2020_28c_0.5.2-test: 2172
# openfibertargets_nov2020_35a_0.5.2-test: 11742
# openfibertargets_nov2020_35b_0.5.2-test: 577
# openfibertargets_nov2020_5_0.5.2-test: 689
# openfibertargets_nov2020_6b_0.5.2-test: 3691
# openfibertargets_nov2020_6c_0.5.2-test: 17927
# openfibertargets_nov2020_10_0.5.3: 42
# openfibertargets_nov2020_1000_0.5.3: 33
# openfibertargets_nov2020_1001a_0.5.3: 2673
# openfibertargets_nov2020_1001b_0.5.3: 154
# openfibertargets_nov2020_11_0.5.3: 3344
# openfibertargets_nov2020_12_0.5.3: 2191
# openfibertargets_nov2020_14_0.5.3: 759
# openfibertargets_nov2020_15_0.5.3: 4317
# openfibertargets_nov2020_17_0.5.3: 5235
# openfibertargets_nov2020_18_0.5.3: 2246
# openfibertargets_nov2020_22_0.5.3: 258
# openfibertargets_nov2020_24_0.5.3: 27351
# openfibertargets_nov2020_25_0.5.3: 23078
# openfibertargets_nov2020_26_0.5.3: 190
# openfibertargets_nov2020_27_0.5.3: 18453
# openfibertargets_nov2020_28a_0.5.3: 2027
# openfibertargets_nov2020_28b_0.5.3: 3129
# openfibertargets_nov2020_28c_0.5.3: 2172
# openfibertargets_nov2020_29_0.5.3: 199
# openfibertargets_nov2020_3_0.5.3: 668
# openfibertargets_nov2020_30_0.5.3: 6
# openfibertargets_nov2020_31_0.5.3: 16
# openfibertargets_nov2020_32_0.5.3: 3019
# openfibertargets_nov2020_33_0.5.3: 568
# openfibertargets_nov2020_35a_0.5.3: 11742
# openfibertargets_nov2020_35b_0.5.3: 577
# openfibertargets_nov2020_35c_0.5.3: 1163
# openfibertargets_nov2020_46_0.5.3: 28610
# openfibertargets_nov2020_8_0.5.3: 10619
# openfibertargets_nov2020_9_0.5.3: 7742
# openfibertargets_nov2020_19a_0.5.3: 7537
# openfibertargets_nov2020_19b_0.5.3: 18
# openfibertargets_nov2020_19c_0.5.3: 46
# manual_nsbh_apogee_0.5.3: 10
# manual_nsbh_boss_0.5.3: 27
# manual_bhm_spiders_comm_0.5.3: 512
# bhm_aqmes_bonus_bright_0.5.4: 1848
# bhm_aqmes_bonus_core_0.5.4: 8421
# bhm_aqmes_bonus_faint_0.5.4: 20471
# bhm_aqmes_wide2_0.5.4: 2875
# bhm_aqmes_wide2_faint_0.5.4: 3879
# mwm_cb_300pc_boss_0.5.4: 18525
# openfibertargets_nov2020_5_0.5.3: 689
# openfibertargets_nov2020_6a_0.5.3: 812
# openfibertargets_nov2020_6b_0.5.3: 3728
# openfibertargets_nov2020_6c_0.5.3: 18156
# manual_bright_target_offsets_1_0.5.3: 1667
# manual_bright_target_offsets_1_g13_0.5.3: 1222
# manual_bright_targets_g13_0.5.3: 1222
# manual_bright_targets_g13_offset_fixed_1_0.5.3: 1222
# manual_bright_targets_g13_offset_fixed_3_0.5.3: 1222
# manual_bright_targets_g13_offset_fixed_5_0.5.3: 1222
# manual_bright_targets_g13_offset_fixed_7_0.5.3: 1222
# manual_fps_position_stars_0.5.3: 13591
# manual_fps_position_stars_10_0.5.3: 53958
# openfibertargets_nov2020_34a_0.5.13: 213184
# openfibertargets_nov2020_34b_0.5.13: 13240
# bhm_csc_boss_0.5.14: 47318
# bhm_csc_boss_0.5.15: 47045
# bhm_csc_apogee_0.5.15: 2363
# bhm_colr_galaxies_lsdr8_0.5.16: 2395
# mwm_yso_cluster_apogee_0.5.17: 16763
# mwm_yso_cluster_boss_0.5.17: 22482
# mwm_yso_cmz_apogee_0.5.17: 244
# mwm_yso_disk_apogee_0.5.17: 9514
# mwm_yso_disk_boss_0.5.17: 12320
# mwm_yso_embedded_apogee_0.5.17: 45
# mwm_yso_nebula_apogee_0.5.17: 3
# mwm_yso_variable_apogee_0.5.17: 15975
# mwm_yso_variable_boss_0.5.17: 15599
# mwm_rv_long_fps_0.5.18: 2507
# mwm_rv_short_fps_0.5.18: 7163
# mwm_cb_300pc_apogee_0.5.19: 72
# mwm_cb_300pc_boss_0.5.19: 7140
# manual_fps_position_stars_apogee_10_0.5.13: 53958
# manual_offset_mwmhalo_off00_0.5.13: 148
# manual_offset_mwmhalo_off05_0.5.13: 148
# manual_offset_mwmhalo_off10_0.5.13: 148
# manual_offset_mwmhalo_off20_0.5.13: 148
# manual_offset_mwmhalo_off30_0.5.13: 148
# manual_offset_mwmhalo_offa_0.5.13: 148
# manual_offset_mwmhalo_offb_0.5.13: 148
# manual_bright_target_offsets_3_0.5.20: 1667
# ops_std_apogee_0.5.22: 6412
# manual_bhm_spiders_comm_lco_0.5.23: 2439
# ops_std_boss_lsdr10_1.0.5: 49174
# mwm_yso_cluster_apogee_1.0.6: 16763
# mwm_yso_cluster_boss_1.0.6: 22482
# mwm_yso_disk_apogee_1.0.6: 8735
# mwm_yso_disk_boss_1.0.6: 11542
# mwm_yso_cmz_apogee_1.0.6: 195
# mwm_yso_variable_apogee_1.0.6: 10185
# mwm_yso_variable_boss_1.0.6: 10015
# mwm_yso_embedded_apogee_1.0.6: 45
# mwm_yso_pms_apogee_zari18pms_1.0.6: 6567
# mwm_yso_pms_boss_sagitta_edr3_1.0.6: 14108
# mwm_yso_pms_boss_zari18pms_1.0.6: 6596
# openfibertargets_nov2020_11_1.0.7: 3344
# openfibertargets_nov2020_18_1.0.7: 2246
# openfibertargets_nov2020_26_1.0.7: 190
# openfibertargets_nov2020_27_1.0.7: 18453
# openfibertargets_nov2020_30_1.0.7: 6
# mwm_yso_nebula_apogee_1.0.8: 3
# manual_mwm_halo_distant_kgiant_1.0.7: 2645
# manual_mwm_halo_mp_bbb_1.0.7: 1526
# openfibertargets_nov2020_10_1.0.7: 42
# openfibertargets_nov2020_1000_1.0.7: 33
# openfibertargets_nov2020_12_1.0.7: 2191
# openfibertargets_nov2020_14_1.0.7: 759
# openfibertargets_nov2020_15_1.0.7: 4317
# openfibertargets_nov2020_22_1.0.7: 258
# openfibertargets_nov2020_24_1.0.7: 27351
# openfibertargets_nov2020_29_1.0.7: 199
# openfibertargets_nov2020_3_1.0.7: 668
# openfibertargets_nov2020_31_1.0.7: 16
# openfibertargets_nov2020_34a_1.0.7: 213190
# openfibertargets_nov2020_34b_1.0.7: 13240
# openfibertargets_nov2020_35b_1.0.7: 577
# openfibertargets_nov2020_35c_1.0.7: 1163
# openfibertargets_nov2020_46_1.0.7: 28610
# openfibertargets_nov2020_5_1.0.7: 689
# openfibertargets_nov2020_6a_1.0.7: 812
# openfibertargets_nov2020_6b_1.0.7: 3728
# openfibertargets_nov2020_6c_1.0.7: 18156
# openfibertargets_nov2020_8_1.0.7: 10619
# openfibertargets_nov2020_9_1.0.7: 7742
# openfibertargets_nov2020_28a_1.0.7: 2027
# openfibertargets_nov2020_33_1.0.10: 568
# bhm_rm_core_1.0.12: 14421
# bhm_rm_known_spec_1.0.12: 28053
# bhm_rm_var_1.0.12: 5240
# bhm_rm_ancillary_1.0.12: 6667
# ops_std_boss_gdr2_1.0.13: 122551
# ops_std_apogee_1.0.14: 6413
# ops_std_eboss_1.0.15: 72677
# ops_std_boss_1.0.16: 125936
# ops_std_boss_red_1.0.16: 12666
# ops_std_boss_tic_1.0.16: 90586
# mwm_snc_100pc_apogee_1.0.17: 1962
# mwm_snc_100pc_boss_1.0.17: 30087
# mwm_bin_gaia_astb_apogee_1.0.19: 253
# mwm_bin_gaia_astb_boss_1.0.19: 1357
# mwm_bin_gaia_sb_apogee_1.0.19: 99
# mwm_bin_gaia_sb_boss_1.0.19: 407
# mwm_yso_pms_apogee_sagitta_edr3_1.0.20: 14084
# mwm_snc_100pc_boss_1.0.24: 30087
# mwm_snc_100pc_boss_1.0.28: 30087
# mwm_yso_disk_apogee_single_1.0.33: 8735
# mwm_yso_disk_boss_single_1.0.33: 11542
# mwm_yso_embedded_apogee_single_1.0.33: 45
# mwm_yso_nebula_apogee_single_1.0.33: 3
# mwm_yso_variable_apogee_single_1.0.33: 10185
# mwm_yso_variable_boss_single_1.0.33: 10015
# mwm_yso_cmz_apogee_single_1.0.33: 195
# mwm_yso_cluster_apogee_single_1.0.33: 16763
# mwm_yso_cluster_boss_single_1.0.33: 22482
# mwm_yso_pms_apogee_sagitta_edr3_single_1.0.33: 14084
# mwm_yso_pms_apogee_zari18pms_single_1.0.33: 6567
# mwm_yso_pms_boss_sagitta_edr3_single_1.0.33: 14108
# mwm_yso_pms_boss_zari18pms_single_1.0.33: 6596
# ops_std_boss_ps1dr2_1.0.29: 124124
# bhm_csc_boss_1.0.37: 33430
# bhm_csc_apogee_1.0.37: 2507
# bhm_gua_dark_1.0.37: 31205
# bhm_gua_bright_1.0.37: 7314
# bhm_spiders_clusters_lsdr10_1.0.37: 11
# bhm_spiders_agn_lsdr10_1.0.37: 8996
# bhm_spiders_agn_hard_1.0.37: 27
# bhm_spiders_agn_gaiadr3_1.0.37: 10729
# bhm_spiders_agn_tda_1.0.37: 136
# bhm_aqmes_med_1.0.37: 1786
# bhm_aqmes_med_faint_1.0.37: 3824
# bhm_aqmes_wide2_1.0.37: 2876
# bhm_aqmes_wide2_faint_1.0.37: 3879
# bhm_aqmes_bonus_core_1.0.37: 8416
# bhm_aqmes_bonus_bright_1.0.37: 1842
# bhm_aqmes_bonus_faint_1.0.37: 20469
# manual_mwm_crosscalib_apogee_1.0.35: 20
# manual_mwm_crosscalib_yso_apogee_1.0.35: 459
# manual_mwm_crosscalib_yso_boss_1.0.35: 459
# manual_mwm_halo_distant_bhb_boss_1.0.35: 3116
# manual_mwm_halo_distant_bhb_boss_single_1.0.35: 3116
# manual_mwm_halo_distant_kgiant_far_boss_1.0.35: 795
# manual_mwm_halo_distant_kgiant_far_boss_single_1.0.35: 795
# manual_mwm_halo_distant_kgiant_near_boss_1.0.35: 1850
# manual_mwm_halo_distant_kgiant_near_boss_single_1.0.35: 1850
# manual_mwm_halo_mp_wise_apogee_1.0.35: 42
# manual_mwm_halo_mp_wise_apogee_single_1.0.35: 42
# manual_mwm_halo_mp_wise_boss_1.0.35: 919
# manual_mwm_halo_mp_wise_boss_single_1.0.35: 919
# manual_mwm_halo_vmp_wise_apogee_1.0.35: 37
# manual_mwm_halo_vmp_wise_apogee_single_1.0.35: 37
# manual_mwm_halo_vmp_wise_boss_1.0.35: 528
# manual_mwm_halo_vmp_wise_boss_single_1.0.35: 528
# bhm_colr_galaxies_lsdr10_1.0.38: 1862
# manual_mwm_validation_cool_apogee_1.0.35: 24
# manual_mwm_validation_cool_boss_1.0.35: 1907
# manual_mwm_validation_hot_boss_1.0.35: 9
# mwm_ob_core_boss_1.0.39: 12305
# mwm_ob_core_boss_single_1.0.39: 12305
# mwm_ob_cepheids_boss_1.0.39: 129
# mwm_bin_rv_long_apogee_1.0.39: 513
# mwm_bin_rv_short_mdwarf_apogee_18epoch_1.0.39: 8341
# mwm_bin_rv_short_mdwarf_apogee_12epoch_1.0.39: 8341
# mwm_bin_rv_short_mdwarf_apogee_08epoch_1.0.39: 8341
# mwm_bin_rv_short_subgiant_apogee_1.0.39: 2406
# mwm_bin_rv_short_rgb_apogee_1.0.39: 1352
# mwm_halo_distant_rrl_boss_single_1.0.39: 2311
# mwm_halo_distant_rrl_boss_1.0.39: 2311
# mwm_halo_vmp_xp_boss_single_1.0.39: 864
# mwm_halo_nmp_xp_boss_single_1.0.39: 3511
# mwm_halo_vmp_xp_apogee_single_1.0.39: 23
# mwm_halo_mp_xp_apogee_single_1.0.39: 70
# mwm_halo_nmp_xp_apogee_single_1.0.39: 132
# mwm_halo_vmp_xp_boss_1.0.39: 864
# mwm_halo_mp_xp_boss_1.0.39: 1888
# mwm_halo_nmp_xp_boss_1.0.39: 3511
# mwm_halo_vmp_xp_apogee_1.0.39: 23
# mwm_halo_mp_xp_apogee_1.0.39: 70
# mwm_halo_nmp_xp_apogee_1.0.39: 132
# mwm_halo_local_high_apogee_single_1.0.39: 166
# mwm_halo_local_high_boss_single_1.0.39: 26104
# mwm_halo_local_low_boss_single_1.0.39: 3076
# mwm_halo_local_high_apogee_1.0.39: 166
# mwm_halo_local_high_boss_1.0.39: 26104
# mwm_halo_local_low_boss_1.0.39: 3076
# mwm_erosita_stars_boss_1.0.40: 6242
# mwm_erosita_compact_boss_1.0.40: 311
# mwm_erosita_compact_boss_shallow_1.0.40: 311
# mwm_halo_mp_xp_boss_single_1.0.41: 1888
# mwm_snc_ext_main_apogee_1.0.41: 475
# mwm_snc_ext_filler_apogee_1.0.41: 6928
# mwm_snc_ext_main_boss_1.0.41: 4893
# mwm_snc_ext_filler_boss_1.0.41: 92955
# mwm_monitor_n188_apogee_long_1.0.42: 5
# mwm_monitor_m67_apogee_short_1.0.42: 17
# mwm_wd_pwd_boss_1.0.42: 36521
# mwm_wd_gaia_boss_1.0.42: 33650
# mwm_cb_galex_mag_boss_1.0.42: 26435
# mwm_cb_galex_vol_boss_1.0.42: 38554
# mwm_cb_xmmom_boss_1.0.42: 649
# mwm_cb_swiftuvot_boss_1.0.42: 573
# mwm_astar_core_boss_1.0.43: 47827
# mwm_astar_core_boss_single_1.0.43: 47827
# mwm_bin_vis_apogee_1.0.44: 829
# mwm_bin_vis_boss_1.0.44: 16893
# mwm_galactic_core_dist_apogee_1.0.44: 3647
# mwm_dust_core_dist_apogee_1.0.45: 42
# manual_mwm_nsbh_apogee_1.0.46: 10
# manual_mwm_nsbh_boss_1.0.46: 27
# mwm_cb_cvcandidates_boss_1.0.47: 834
# mwm_legacy_ir2opt_boss_1.0.47: 24505
# bhm_rm_core_1.0.48: 14362
# bhm_rm_known_spec_1.0.48: 28034
# bhm_rm_var_1.0.48: 5240
# bhm_rm_ancillary_1.0.48: 6667
# mwm_tess_2min_apogee_1.0.49: 6869
# mwm_tess_rgb_apogee_1.0.49: 8060
# manual_mwm_planet_gaia_astrometry_apogee_1.0.46: 4417
# manual_mwm_planet_known_apogee_1.0.46: 10
# manual_mwm_planet_tess_eb_apogee_1.0.46: 98
# manual_mwm_planet_tess_pc_apogee_1.0.46: 74

# %% [markdown]
# # Flags have attributes
#
# The counts above are for targets assigned to a specific carton, with a specific version. Sometimes we don't care about the carton version and we just want to count by the effective number of targets assigned to that carton (over all versions), or we might want to count by the number of targets assigned to each mapper, or some other attribute.
#
# The `TargetingFlags.mapping` attribute contains a reference dictionary for all cartons, including their attributes. Here's how we can count targets by those attributes:

# %%
for mapper, count in flags.count_by_attribute("mapper").items():
    print(f"{mapper}: {count:,}")
# Out:
# na: 0
# mwm: 460,377
# ops: 325,569
# bhm: 65,114
# open: 363,471

# %%
for program, count in flags.count_by_attribute("program").items():
    print(f"{program}: {count:,}")
# Out:
# na: 0
# mwm_snc: 131,249
# mwm_cb: 83,708
# mwm_halo: 73,865
# mwm_yso: 59,667
# mwm_rv: 10,209
# mwm_ob: 102,320
# ops_std: 281,742
# mwm_wd: 37,834
# mwm_gg: 5,264
# mwm_planet: 10,269
# bhm_aqmes: 4,337
# bhm_filler: 41,024
# mwm_tessrgb: 8,065
# bhm_csc: 52,291
# ops_sky: 0
# bhm_rm: 29,196
# bhm_spiders: 13,190
# mwm_dust: 81
# mwm_legacy: 24,789
# mwm_galactic: 6,336
# mwm_filler: 50,052
# mwm_tess_ob: 0
# mwm_erosita: 8,323
# open_fiber: 363,471
# commissioning: 58,684
# SKY: 0
# mwm_tessob: 0
# mwm_magcloud: 0
# mwm_bin: 14,175
# mwm_validation: 2,413
# mwm_monitor: 22

# %% [markdown]
# # I own a carton. Where are my spectra?
#
# You can efficiently construct boolean masks to select spectra that are assigned to a carton, program, mapper, or any other attribute.
#
# The easiest way to do this is with the following methods:
# - `TargetingFlags.in_carton_pk`: If you know the database primary key (`targetdb.carton.pk`) of your carton
# - `TargetingFlags.in_carton_name`: If you know the name of your carton.
# - `TargetingFlags.in_carton_label`: If you know the name and version (name_ver) of your carton
# - `TargetingFlags.in_mapper`: To select by mapper (e.g., BHM, MWM)
# - `TargetingFlags.in_program`: To select by program name.
# - `TargetingFlags.in_alt_name`: To select by alternative name, curated with thanks by Marina Koukel.
# - `TargetingFlags.in_alt_program`: To select by alternative program name, curated with thanks by Marina Koukel.
#
# If you're not sure what your carton's alternative name or program is, you might find these properties useful:
#
# - `TargetingFlags.all_mappers`: a tuple of all unique mapper names;
# - `TargetingFlags.all_programs`: a tuple of all unique program names;
# - `TargetingFlags.all_carton_names`: a tuple of all unique carton names;
# - `TargetingFlags.all_alt_carton_names`: a tuple of all unique alternative names;
# - `TargetingFlags.all_alt_programs`: a tuple of all unique alternative program names;
#
# or you can look this up from `TargetingFlags.mapping`.

# %%
print("Mappers:")
for mapper in flags.all_mappers:
    print(f"\t{mapper}")
    
print("Programs")
for program in flags.all_programs:
    print(f"\t{program}")

print("Cartons names")
for name in flags.all_carton_names:
    print(f"\t{name}")

print("Alternative cartons names")
for alt_name in flags.all_alt_carton_names:
    print(f"\t{alt_name}")

print("Alternative programs")
for alt_program in flags.all_alt_programs:
    print(f"\t{alt_program}")
# Out:
# Mappers:
# 	open
# 	ops
# 	bhm
# 	na
# 	mwm
# Programs
# 	mwm_rv
# 	mwm_magcloud
# 	open_fiber
# 	mwm_yso
# 	mwm_halo
# 	mwm_tess_ob
# 	mwm_tessob
# 	mwm_legacy
# 	bhm_rm
# 	bhm_filler
# 	mwm_erosita
# 	mwm_cb
# 	mwm_validation
# 	mwm_tessrgb
# 	SKY
# 	bhm_aqmes
# 	mwm_ob
# 	mwm_filler
# 	ops_std
# 	mwm_bin
# 	ops_sky
# 	commissioning
# 	mwm_gg
# 	na
# 	mwm_wd
# 	mwm_planet
# 	mwm_galactic
# 	bhm_csc
# 	bhm_spiders
# 	mwm_dust
# 	mwm_snc
# 	mwm_monitor
# Cartons names
# 	mwm_monitor_m15_apogee_long
# 	bhm_rm_var
# 	mwm_monitor_m67_apogee_long
# 	mwm_cb_300pc_boss
# 	mwm_halo_local_low_boss
# 	mwm_monitor_n188_apogee_long
# 	openfibertargets_nov2020_27
# 	openfibertargets_nov2020_24
# 	mwm_bin_rv_short_mdwarf_apogee_12epoch
# 	mwm_halo_vmp_xp_boss
# 	openfibertargets_nov2020_6c
# 	mwm_halo_local_low_apogee_single
# 	mwm_yso_nebula_apogee
# 	manual_mwm_crosscalib_apogee
# 	mwm_halo_nmp_xp_boss
# 	mwm_ob_cepheids_boss
# 	openfibertargets_mwm_lvm_als_apogee
# 	ops_std_boss_gdr2
# 	bhm_colr_galaxies_lsdr10
# 	mwm_snc_250pc_apogee
# 	bhm_rm_known_spec
# 	openfibertargets_mwm_lvm_lmc_boss
# 	mwm_bin_rv_short_subgiant_apogee_12epoch
# 	mwm_yso_cluster_boss_single
# 	mwm_halo_bb_boss
# 	mwm_bin_gaia_astb_boss
# 	mwm_bin_vis_apogee
# 	manual_nsbh_boss
# 	openfibertargets_nov2020_28b
# 	bhm_spiders_clusters_ps1dr2
# 	openfibertargets_nov2020_34a
# 	openfibertargets_mwm_sphx_apogee
# 	mwm_cb_swiftuvot_boss
# 	bhm_csc_boss-bright
# 	manual_mwm_planet_transiting_bd_apogee
# 	openfibertargets_bhm_hightderates_psb_boss
# 	openfibertargets_nov2020_31
# 	openfibertargets_nov2020_26
# 	openfibertargets_nov2020_29
# 	mwm_cb_uvex2
# 	mwm_yso_cluster
# 	openfibertargets_mwm_snc_further_ext_boss
# 	manual_offset_mwmhalo_off10
# 	mwm_rv_short-rm
# 	manual_fps_position_stars_lco_apogee_10
# 	mwm_yso_embedded_apogee
# 	bhm_spiders_clusters-efeds-ls-redmapper
# 	manual_fps_position_stars_apogee_10
# 	openfibertargets_nov2020_12
# 	openfibertargets_bhm_morexray_boss
# 	manual_bhm_spiders_comm_lco
# 	mwm_halo_vmp_xp_apogee
# 	mwm_halo_nmp_xp_apogee_triple
# 	mwm_halo_local_high_boss_triple
# 	openfibertargets_mwm_compactbinaries_boss
# 	mwm_rv_long_bplates
# 	bhm_aqmes_wide3-faint
# 	mwm_planet_tess
# 	mwm_cb_cvcandidates
# 	mwm_yso_variable_apogee_single
# 	mwm_halo_sm
# 	manual_mwm_planet_sophie_apogee
# 	openfibertargets_mwm_lvm_als_boss
# 	bhm_aqmes_wide3
# 	openfibertargets_nov2020_6a
# 	openfibertargets_mwm_snc_further_ext_apogee_dark
# 	manual_mwm_halo_mp_bbb
# 	openfibertargets_nov2020_1001b
# 	bhm_spiders_clusters_lsdr8
# 	ops_sky_apogee_good
# 	manual_bright_target_offsets_1
# 	manual_offset_mwmhalo_off05
# 	openfibertargets_bhm_varagn_boss
# 	bhm_csc_boss_d3
# 	bhm_aqmes_bonus-bright
# 	openfibertargets_nov2020_15
# 	bhm_csc_boss_dark
# 	manual_mwm_halo_distant_kgiant_far_boss_single
# 	mwm_yso_pms_boss_sagitta_edr3_single
# 	mwm_cb_gaiagalex_apogee
# 	mwm_snc_100pc_low_lum_boss_single
# 	mwm_dust_core
# 	manual_offset_mwmhalo_offa
# 	manual_mwm_crosscalib_yso_boss
# 	ops_std_boss_red
# 	mwm_snc_100pc_boss
# 	mwm_yso_pms_apogee
# 	openfibertargets_mwm_tess_ellipsoidals_repeat_apogee
# 	manual_mwm_planet_tess_eb_apogee
# 	mwm_bin_gaia_sb_apogee
# 	manual_mwm_halo_vmp_wise_apogee_single
# 	bhm_aqmes_med
# 	mwm_snc_250pc
# 	mwm_erosita_stars_boss
# 	mwm_cb_cvcandidates_apogee
# 	manual_mwm_halo_distant_kgiant_far_boss
# 	openfibertargets_mwm_ellipsoidal_bh_ns_candidates_boss
# 	manual_offset_mwmhalo_off20
# 	bhm_spiders_agn_tda_d3
# 	manual_bright_targets_g13_offset_fixed_1
# 	mwm_galactic_core_dist_apogee_extra
# 	ops_sky_boss_best
# 	mwm_monitor_m15_apogee_short
# 	mwm_erosita_compact_boss_shallow
# 	openfibertargets_nov2020_47a
# 	openfibertargets_mwm_subgiants_apogee
# 	mwm_yso_disk_apogee_single
# 	bhm_spiders_clusters-efeds-hsc-redmapper
# 	mwm_wd_gaia_boss
# 	openfibertargets_mwm_asassn_eb_apogee
# 	mwm_halo_mp_xp_boss_single
# 	mwm_tess_2min_apogee
# 	mwm_snc_ext_filler_apogee
# 	manual_mwm_halo_vmp_wise_apogee_triple
# 	mwm_bin_vis_boss
# 	mwm_yso_ob
# 	mwm_yso_s1
# 	manual_mwm_planet_ca_legacy_apogee
# 	openfibertargets_mwm_ztf_scope_apogee
# 	bhm_spiders_agn_hard_d3
# 	mwm_cb_300pc_apogee
# 	mwm_wd_gaia_boss_2x1
# 	mwm_legacy_ir2opt
# 	mwm_halo_vmp_xp_apogee_single
# 	mwm_halo_vmp_xp_apogee_triple
# 	mwm_halo_local_high_boss_single
# 	mwm_halo_nmp_xp_boss_triple
# 	manual_mwm_planet_gaia_astrometry_apogee
# 	na
# 	openfibertargets_nov2020_18
# 	openfibertargets_nov2020_25
# 	ops_sky_apogee
# 	manual_mwm_halo_mp_wise_apogee_triple
# 	bhm_spiders_agn_sep_d3
# 	mwm_yso_pms_apogee_sagitta_edr3
# 	mwm_yso_variable_boss_single
# 	openfibertargets_nov2020_32
# 	mwm_yso_s2
# 	mwm_galactic_core
# 	mwm_halo_bb
# 	openfibertargets_mwm_subgiant_nataf24_apogee
# 	manual_offset_mwmhalo_offb
# 	openfibertargets_nov2020_14
# 	openfibertargets_nov2020_34b
# 	bhm_aqmes_wide1
# 	bhm_spiders_clusters-efeds-sdss-redmapper
# 	mwm_cb_gaiagalex_boss
# 	openfibertargets_nov2020_35c
# 	manual_mwm_validation_hot_boss
# 	bhm_spiders_agn_hard
# 	mwm_snc_100pc_apogee
# 	openfibertargets_nov2020_35a
# 	mwm_halo_local_low_boss_single
# 	manual_mwm_dust_ullyses
# 	openfibertargets_mwm_lvm_smc_apogee
# 	manual_bright_targets_g13_offset_fixed_3
# 	openfibertargets_mwm_gaia_var_cvs_boss
# 	openfibertargets_mwm_cvcandidates_boss
# 	mwm_halo_local_high_apogee_single
# 	openfibertargets_mwm_bhc_gdr4_apogee
# 	openfibertargets_nov2020_19b
# 	bhm_spiders_agn_efeds_stragglers
# 	manual_mwm_planet_harps_apogee
# 	manual_fps_position_stars
# 	bhm_spiders_agn_supercosmos
# 	bhm_rm_known-spec
# 	openfibertargets_mwm_sphx_boss
# 	mwm_yso_pms_apogee_sagitta_edr3_single
# 	manual_mwm_halo_distant_kgiant_near_boss_single
# 	openfibertargets_mwm_vmr_boss
# 	ops_sky_apogee_best
# 	mwm_yso_disk_boss_single
# 	mwm_halo_local_low_boss_triple
# 	bhm_colr_galaxies_lsdr8
# 	mwm_halo_mp_xp_apogee_triple
# 	manual_nsbh_apogee
# 	bhm_rm_core
# 	manual_bright_targets_g13_offset_fixed_7
# 	mwm_halo_distant_rrl_boss_single
# 	bhm_spiders_agn_lsdr8
# 	mwm_astar_core_boss_single
# 	openfibertargets_nov2020_47e
# 	mwm_yso_pms_boss_zari18pms
# 	mwm_halo_nmp_xp_apogee
# 	mwm_yso_variable_apogee
# 	mwm_wd_gaia_boss_1x2
# 	mwm_yso_pms_boss_sagitta_edr3
# 	mwm_yso_nebula_apogee_single
# 	mwm_ob_core_boss
# 	bhm_gua_bright
# 	bhm_spiders_clusters_efeds_stragglers
# 	bhm_gua_dark
# 	openfibertargets_nov2020_35b
# 	mwm_halo_vmp_xp_boss_single
# 	mwm_galactic_core_dist_apogee_sparse
# 	bhm_aqmes_bonus-dark
# 	mwm_wd_pwd_boss
# 	mwm_tessrgb_core
# 	manual_mwm_halo_vmp_wise_boss_single
# 	mwm_erosita_compact_boss_d3
# 	mwm_yso_pms_boss
# 	mwm_tess_planet
# 	ops_std_boss
# 	manual_mwm_planet_known_apogee
# 	bhm_spiders_agn_ps1dr2
# 	openfibertargets_nov2020_5
# 	bhm_spiders_agn_skymapperdr2
# 	mwm_bin_rv_short_mdwarf_apogee_08epoch
# 	mwm_snc_100pc
# 	mwm_yso_variable_boss
# 	bhm_spiders_agn_gaiadr3
# 	openfibertargets_nov2020_19c
# 	mwm_halo_sm_boss
# 	bhm_rm_xrayqso
# 	bhm_aqmes_bonus_faint
# 	mwm_bin_gaia_astb_apogee
# 	manual_mwm_halo_mp_wise_apogee_single
# 	openfibertargets_mwm_ztf_lomb_boss
# 	ops_std_eboss
# 	bhm_spiders_agn_gaiadr2
# 	openfibertargets_mwm_tessperiodic_boss
# 	manual_bright_target_offsets_3
# 	openfibertargets_nov2020_33
# 	bhm_spiders_agn_tda
# 	mwm_rv_long_fps
# 	openfibertargets_nov2020_47b
# 	bhm_spiders_clusters-efeds-erosita
# 	mwm_yso_disk_apogee
# 	bhm_aqmes_med_faint
# 	manual_mwm_planet_sphere_apogee
# 	openfibertargets_mwm_snc_further_ext_apogee_bright
# 	mwm_snc_ext_main_boss
# 	mwm_erosita_stars
# 	mwm_halo_mp_xp_apogee_single
# 	manual_mwm_halo_mp_wise_apogee
# 	mwm_monitor_m67_apogee_short
# 	bhm_aqmes_bonus_core
# 	mwm_cb_uvex4
# 	mwm_gg_core
# 	manual_bright_targets_g13
# 	mwm_bin_rv_short_rgb_apogee
# 	mwm_tess_ob
# 	manual_mwm_halo_mp_wise_boss_single
# 	manual_mwm_halo_distant_kgiant
# 	openfibertargets_mwm_stripped_stars_plane_boss
# 	bhm_gua_dark_d3
# 	mwm_cb_uvex3
# 	mwm_ob_core_boss_single
# 	mwm_halo_local_low_apogee
# 	mwm_wd_pwd_boss_1x3
# 	openfibertargets_mwm_ztf_lomb_apogee
# 	mwm_wd_pwd_boss_2x1
# 	mwm_yso_cmz
# 	ops_std_boss_ps1dr2
# 	bhm_spiders_agn_lsdr10
# 	mwm_rv_long-rm
# 	bhm_aqmes_wide2
# 	manual_bhm_spiders_comm
# 	ops_std_boss_lsdr10
# 	ops_sky_boss_fallback
# 	mwm_cb_300pc
# 	mwm_rv_long-bplates
# 	mwm_rv_short_fps
# 	openfibertargets_nov2020_22
# 	mwm_cb_xmmom_boss
# 	mwm_halo_nmp_xp_boss_single
# 	bhm_colr_galaxies_lsdr10_d3
# 	mwm_astar_core_boss
# 	manual_mwm_halo_distant_bhb_boss_triple
# 	manual_mwm_halo_vmp_wise_boss_triple
# 	manual_mwm_halo_distant_kgiant_near_boss
# 	openfibertargets_bhm_hightderates_qbs_boss
# 	openfibertargets_nov2020_1001a
# 	bhm_spiders_clusters_lsdr10_d3
# 	mwm_yso_disk_boss
# 	openfibertargets_mwm_bhc_gdr4_boss
# 	mwm_bin_rv_short_mdwarf_apogee_18epoch
# 	bhm_aqmes_wide1_faint
# 	manual_mwm_boss_only_cluster_jan_2025_low_priority
# 	mwm_yso_pms_apogee_zari18pms_single
# 	bhm_spiders_agn_lsdr10_d3
# 	openfibertargets_mwm_lvm_smc_boss
# 	mwm_yso_ob_boss
# 	mwm_yso_cmz_apogee
# 	manual_mwm_tess_ob
# 	bhm_spiders_agn_sep
# 	manual_mwm_halo_vmp_wise_boss
# 	mwm_snc_100pc_boss_single
# 	openfibertargets_nov2020_28c
# 	openfibertargets_mwm_tessperiodic_apogee
# 	mwm_ob_core
# 	mwm_erosita_compact_gen
# 	mwm_yso_cluster_apogee_single
# 	bhm_csc_apogee
# 	manual_mwm_magcloud_massive_apogee
# 	manual_mwm_halo_distant_bhb_boss
# 	mwm_wd_gaia_boss_1x3
# 	manual_mwm_halo_distant_bhb_boss_single
# 	mwm_halo_local_high_apogee_triple
# 	mwm_halo_nmp_xp_apogee_single
# 	manual_mwm_dust_gaia_madgics_dib_dr3
# 	mwm_snc_250pc_boss
# 	openfibertargets_nov2020_8
# 	manual_mwm_magcloud_symbiotic_apogee
# 	mwm_dust_core_dist_apogee
# 	mwm_halo_mp_xp_apogee
# 	mwm_halo_vmp_xp_boss_triple
# 	openfibertargets_nov2020_10
# 	mwm_erosita_compact_boss
# 	openfibertargets_mwm_ztf_scope_boss
# 	mwm_snc_100pc_bright_boss_single
# 	mwm_cb_uvex5
# 	openfibertargets_mwm_vmr_apogee
# 	mwm_wd_core
# 	ops_std_boss_lsdr8
# 	mwm_halo_mp_xp_boss_triple
# 	manual_mwm_halo_mp_wise_boss
# 	mwm_rv_long-fps
# 	mwm_yso_pms_boss_zari18pms_single
# 	manual_mwm_validation_hot_apogee
# 	manual_mwm_nsbh_boss
# 	openfibertargets_bhm_lofarradio_boss
# 	manual_mwm_magcloud_massive_boss
# 	manual_mwm_halo_distant_kgiant_far_boss_triple
# 	openfibertargets_mwm_hypervelocity_stars_boss
# 	mwm_rv_short-fps
# 	bhm_csc_boss
# 	manual_mwm_halo_vmp_wise_apogee
# 	ops_std_apogee
# 	mwm_halo_local_high_boss
# 	openfibertargets_nov2020_1000
# 	mwm_cb_galex_vol_boss
# 	mwm_yso_s2-5
# 	mwm_yso_cluster_boss
# 	mwm_cb_gaiagalex
# 	mwm_yso_cluster_apogee
# 	manual_mwm_boss_only_cluster_jan_2025_high_priority
# 	mwm_bin_gaia_sb_boss
# 	bhm_aqmes_wide2_faint
# 	bhm_spiders_clusters_lsdr10
# 	mwm_wd_pwd_boss_1x2
# 	mwm_legacy_ir2opt_boss
# 	bhm_aqmes_bonus_bright
# 	manual_mwm_nsbh_apogee
# 	mwm_yso_cmz_apogee_single
# 	bhm_csc_boss_bright
# 	manual_mwm_validation_cool_boss
# 	manual_mwm_halo_mp_wise_boss_triple
# 	mwm_snc_ext_main_apogee
# 	manual_bright_targets_g13_offset_fixed_5
# 	mwm_galactic_core_dist_apogee
# 	openfibertargets_nov2020_28a
# 	mwm_ob_cepheids
# 	mwm_halo_local_low_apogee_triple
# 	mwm_cb_galex_mag_boss
# 	manual_mwm_tess_ob_apogee
# 	bhm_aqmes_wide2-faint
# 	mwm_halo_mp_xp_boss
# 	bhm_aqmes_med-faint
# 	openfibertargets_nov2020_30
# 	manual_mwm_halo_distant_kgiant_near_boss_triple
# 	manual_mwm_validation_cool_apogee
# 	mwm_rv_short-bplates
# 	mwm_yso_embedded_apogee_single
# 	manual_mwm_planet_gpi_apogee
# 	mwm_yso_pms_apogee_zari18pms
# 	mwm_yso_ob_apogee
# 	mwm_yso_s3
# 	manual_mwm_crosscalib_yso_apogee
# 	openfibertargets_nov2020_19a
# 	openfibertargets_nov2020_47c
# 	openfibertargets_mwm_als_boss
# 	ops_sky_boss_good
# 	mwm_cb_cvcandidates_boss
# 	ops_apogee_stds
# 	openfibertargets_nov2020_46
# 	mwm_magcloud_rgb_boss
# 	mwm_cb_uvex1
# 	mwm_bin_rv_long_apogee
# 	bhm_spiders_agn_gaiadr3_d3
# 	mwm_snc_ext_filler_boss
# 	mwm_monitor_n188_apogee_short
# 	bhm_spiders_agn-efeds
# 	openfibertargets_nov2020_47d
# 	manual_fps_position_stars_10
# 	openfibertargets_mwm_lvm_lmc_apogee
# 	manual_offset_mwmhalo_off30
# 	ops_std_boss-red
# 	mwm_bin_rv_short_subgiant_apogee
# 	manual_mwm_planet_tess_pc_apogee
# 	openfibertargets_nov2020_9
# 	manual_offset_mwmhalo_off00
# 	ops_sky_boss
# 	ops_std_boss_tic
# 	openfibertargets_bhm_racsradio_boss
# 	bhm_rm_ancillary
# 	mwm_erosita_compact_var
# 	mwm_halo_distant_rrl_boss
# 	mwm_halo_local_high_apogee
# 	openfibertargets_nov2020_6b
# 	openfibertargets_nov2020_17
# 	mwm_tess_rgb_apogee
# 	manual_mwm_validation_rv_apogee
# 	openfibertargets_bhm_quaia_boss
# 	mwm_magcloud_agb_apogee
# 	bhm_csc_boss-dark
# 	openfibertargets_mwm_more_ob_boss
# 	mwm_halo_distant_rrl_boss_triple
# 	openfibertargets_nov2020_3
# 	openfibertargets_nov2020_11
# 	manual_bright_target_offsets_1_g13
# Alternative cartons names
# 	mwm_validation_rv
# 	mwm_bin_rv_long
# 	mwm_yso_variable
# 	mwm_yso_ob
# 	mwm_bin_rv_short_mdwarf
# 	mwm_tess_2min
# 	manual_mwm_planet_transiting_bd
# 	ops_std
# 	mwm_bin_rv_short_subgiant
# 	mwm_legacy_ir2opt
# 	mwm_crosscalib
# 	ops_sky
# 	na
# 	mwm_halo_openfiber
# 	mwm_erosita_stars
# 	mwm_snc_openfiber
# 	mwm_magcloud_agb
# 	manual_offset_mwmhalo
# 	mwm_bin_rv_short
# 	mwm_yso_disk
# 	mwm_cluster_openfiber
# 	mwm_tess_ob
# 	manual_mwm_halo_distant_kgiant
# 	mwm_bin_vis
# 	mwm_monitor_apogee_m15
# 	bhm_filler
# 	mwm_galactic_core
# 	mwm_halo_mp_xp
# 	manual_mwm_halo_mp_wise
# 	mwm_halo_bb
# 	bhm_openfiber
# 	manual_mwm_nsbh
# 	mwm_yso_cmz
# 	mwm_bin_gaia_astb
# 	mwm_validation_cool
# 	mwm_validation_hot
# 	mwm_bin_rv_short_rgb
# 	mwm_ztf_openfiber
# 	mwm_yso_cluster
# 	mwm_ob_cepheids
# 	mwm_wd
# 	mwm_cb_300pc
# 	mwm_yso_openfiber
# 	mwm_halo_distant_rrl
# 	mwm_halo_local
# 	mwm_magcloud_rgb
# 	manual_mwm_planet_gpi
# 	bhm_csc
# 	mwm_snc
# 	mwm_bin_gaia_sb
# 	mwm_cb_swiftuvot
# 	manual_mwm_planet_tess_eb
# 	mwm_ob_openfiber
# 	manual_mwm_planet_known
# 	mwm_nsbh_openfiber
# 	bhm_rm
# 	mwm_cb_cvcandidates
# 	mwm_magcloud_massive
# 	mwm_halo_sm
# 	mwm_bin_openfiber
# 	bhm_aqmes
# 	mwm_openfiber
# 	mwm_validation_openfiber
# 	mwm_magcloud_symbiotic
# 	mwm_yso_embedded
# 	manual_mwm_planet_tess_pc
# 	mwm_ob_core
# 	mwm_dust_core
# 	mwm_cb_xmmom
# 	manual_mwm_halo_distant_bhb
# 	mwm_cluster
# 	manual_mwm_planet_gaia_astrometry
# 	mwm_cb_galex
# 	manual_mwm_planet_ca_legacy
# 	mwm_erosita_compact
# 	mwm_cb_openfiber
# 	mwm_yso_pms
# 	mwm_monitor_apogee_n188
# 	manual_fps_position_stars_apogee
# 	mwm_crosscalib_yso
# 	manual_mwm_planet_harps
# 	mwm_monitor_apogee_m67
# 	manual_mwm_planet_sophie
# 	mwm_tess_rgb
# 	manual_mwm_planet_sphere
# 	mwm_yso_nebula
# 	bhm_spiders
# 	mwm_dust
# Alternative programs
# 	open_fiber
# 	halo
# 	dust
# 	legacy
# 	tess
# 	monitor
# 	magcloud
# 	snc
# 	tessob
# 	nsbh
# 	std
# 	tessrgb
# 	filler
# 	csc
# 	erosita
# 	spiders
# 	bin
# 	planet
# 	yso
# 	sky
# 	riller
# 	aqmes
# 	ob
# 	validation
# 	cluster
# 	commissioning
# 	cb
# 	na
# 	wd
# 	galactic
# 	rm

# %% [markdown]
# ### Select by Mapper
# If you want to check which rows are in a particular mapper

# %%
# Select things assigned to MWM
mwm_mask = flags.in_mapper("mwm")
mwm_mask
# Out:
# array([ True, False,  True, ..., False,  True, False])

# %%
print(f"There are {np.sum(flags.in_mapper('mwm')):,} things assigned to MWM")
# Out:
# There are 460,377 things assigned to MWM

# %% [markdown]
# ### Select by Program
# If you want to check which rows are in a particular program

# %%
flags.in_program("mwm_wd")
# Out:
# array([False, False,  True, ..., False, False, False])

# %% [markdown]
# ### Select by name
# If you want to check which rows are in a particular carton

# %%
flags.in_carton_name("mwm_snc_250pc")
# Out:
# array([False, False, False, ..., False, False, False])

# %% [markdown]
# ## I have a target, how was it targeted?
#
# If you have a CATALOGID or SDSS_ID and would like to know the targeting cartons for that source
#
# The easiest way to do this is with the following methods:
# - `TargetingFlags.get_carton_pk`: If you want to know the database primary key (`targetdb.carton.pk`) of the cartons that include your target
# - `TargetingFlags.get_carton_name`: If you want know the name of the cartons that include your target
# - `TargetingFlags.get_carton_label`: If you want know the name and version (name_ver) of the cartons that include your target
# - `TargetingFlags.get_mapper`: If you want to know the mapper (e.g., BHM, MWM) of the cartons that include your target
# - `TargetingFlags.get_program`: If you want to know the program name of the cartons that include your target
# - `TargetingFlags.get_alt_name`: If you want to know the alternative name (curated with thanks by Marina Koukel) of the cartons that include your target
# - `TargetingFlags.get_alt_program`: If you want to know the alternative program name (curated with thanks by Marina Koukel) of the cartons that include your target

# %%
catalogid = 27021598754184543
idx = np.where((boss_data["CATALOGID21"] == catalogid) |
               (boss_data["CATALOGID25"] == catalogid) | 
               (boss_data["CATALOGID31"] == catalogid))[0]

flags.get_carton_label(idx[0])
# Out:
# (['mwm_yso_s3_0.1.0',
#   'mwm_yso_cluster_0.1.0',
#   'mwm_yso_variable_apogee_0.5.0',
#   'mwm_yso_variable_boss_0.5.0',
#   'mwm_yso_cluster_apogee_0.5.0',
#   'mwm_yso_cluster_boss_0.5.0',
#   'mwm_yso_cluster_apogee_0.5.17',
#   'mwm_yso_cluster_boss_0.5.17',
#   'mwm_yso_variable_apogee_0.5.17',
#   'mwm_yso_variable_boss_0.5.17',
#   'mwm_yso_cluster_apogee_1.0.6',
#   'mwm_yso_cluster_boss_1.0.6',
#   'mwm_yso_variable_apogee_1.0.6',
#   'mwm_yso_variable_boss_1.0.6',
#   'mwm_yso_variable_apogee_single_1.0.33',
#   'mwm_yso_variable_boss_single_1.0.33',
#   'mwm_yso_cluster_apogee_single_1.0.33',
#   'mwm_yso_cluster_boss_single_1.0.33'],)

# %%
sdss_id = 87406300
idx = np.where(boss_data["SDSS_ID"] == sdss_id)[0]
flags.get_carton_label(idx[0])
# Out:
# (['mwm_yso_s3_0.1.0',
#   'mwm_yso_cluster_0.1.0',
#   'mwm_yso_variable_apogee_0.5.0',
#   'mwm_yso_variable_boss_0.5.0',
#   'mwm_yso_cluster_apogee_0.5.0',
#   'mwm_yso_cluster_boss_0.5.0',
#   'mwm_yso_cluster_apogee_0.5.17',
#   'mwm_yso_cluster_boss_0.5.17',
#   'mwm_yso_variable_apogee_0.5.17',
#   'mwm_yso_variable_boss_0.5.17',
#   'mwm_yso_cluster_apogee_1.0.6',
#   'mwm_yso_cluster_boss_1.0.6',
#   'mwm_yso_variable_apogee_1.0.6',
#   'mwm_yso_variable_boss_1.0.6',
#   'mwm_yso_variable_apogee_single_1.0.33',
#   'mwm_yso_variable_boss_single_1.0.33',
#   'mwm_yso_cluster_apogee_single_1.0.33',
#   'mwm_yso_cluster_boss_single_1.0.33'],)

# %% [markdown]
# ## About this notebook
#
# This notebook was created to give an example of using the `semaphore` tool with the mwmAllVisit file
#
# **Authors**: Andy Casey (andrew.casey@monash.edu), Sean Morrison (smorris0@illinois.edu)
#
# **Last Update**: 2025 Oct 22
#
# If you use `astropy`  for published research, please cite the
# authors. Follow this link for more information about citing `astropy`:
#
# * [Citing `astropy`](https://www.astropy.org/acknowledging.html)
#
# And of course please [cite](https://sdss.org/collaboration/citing-sdss/) SDSS when you use our data.
